# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem.Scaffolds.MurckoScaffold import MakeScaffoldGeneric, GetScaffoldForMol, MurckoScaffoldSmiles
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import AllChem, MACCSkeys
from rdkit.SimDivFilters import rdSimDivPickers
from rdkit.Chem.Fingerprints import FingerprintMols
from rdkit import DataStructs

# %%
mol = Chem.MolFromSmiles('CCOc1cn2ncc(C#N)c2c(c1)c1ccc(nc1)N1CCNCC1')
mol

# %%
scaffold = GetScaffoldForMol(mol)
scaffold

# %%
scaffold_ = MakeScaffoldGeneric(scaffold)
scaffold_

# %%
scaffold_1 = GetScaffoldForMol(scaffold)
scaffold_1

# %%
scaffold_2 = MakeScaffoldGeneric(scaffold_1)
scaffold_2

# %%
 MurckoScaffoldSmiles('Cc1cc(Oc2nccc(CCC)c2)ccc1')
# Out:
# 'c1ccc(Oc2ccccn2)cc1'

# %%
Chem.MolFromSmiles('c1ccc(Oc2ccccn2)cc1')

# %%
Chem.MolFromSmiles('Cc1cc(Oc2nccc(CCC)c2)ccc1')

# %%
MurckoScaffoldSmiles(mol=Chem.MolFromSmiles('Cc1cc(Oc2nccc(CCC)c2)ccc1'))
# Out:
# 'c1ccc(Oc2ccccn2)cc1'

# %%
fps = AllChem.GetMorganFingerprint(mol, 1, useFeatures=True)
fps
